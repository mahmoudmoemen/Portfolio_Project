# %% [markdown]
# First: import needed libraries

# %%
import pandas as pd
import numpy
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv(r'C:\Users\Start\Documents\Motor_Vehicle_Crashes.csv')

# %%
df
# Out:
#          CRASH DATE   CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0        09/11/2021  02:39:00 AM       NaN       NaN        NaN        NaN
# 1        03/26/2022  11:45:00 AM       NaN       NaN        NaN        NaN
# 2        06/29/2022  06:55:00 AM       NaN       NaN        NaN        NaN
# 3        09/11/2021  09:35:00 AM  BROOKLYN   11208.0  40.667202 -73.866500
# 4        12/14/2021  08:13:00 AM  BROOKLYN   11233.0  40.683304 -73.917274
# ...             ...          ...       ...       ...        ...        ...
# 1048570  08/23/2016  04:55:00 PM       NaN       NaN  40.692722 -73.968750
# 1048571  09/11/2016  02:45:00 PM       NaN       NaN  40.733430 -73.868890
# 1048572  09/09/2016  05:00:00 PM       NaN       NaN  40.770065 -73.959274
# 1048573  09/05/2016  09:12:00 PM       NaN       NaN  40.617764 -74.135700
# 1048574  08/25/2016  02:00:00 PM  BROOKLYN   11226.0  40.650806 -73.949580
#
# ...

# %% [markdown]
# Second: Data Exploration

# %%
df.shape
# Out:
# (1048575, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   CRASH DATE                     1048575 non-null  object
#  1   CRASH TIME                     1048575 non-null  object
#  2   BOROUGH                        671900 non-null   object
#  3   ZIP CODE                       671716 non-null   float64
#  4   LATITUDE                       973789 non-null   float64
#  5   LONGITUDE                      973789 non-null   float64
#  6   LOCATION                       973789 non-null   object
#  7   ON STREET NAME                 791565 non-null   object
#  8   CROSS STREET NAME              505583 non-null   object
#  9   OFF STREET NAME                255682 non-null   object
#  10  NUMBER OF PERSONS INJURED      1048558 non-null  float64
# ...

# %%
df.describe()
# Out:
#             ZIP CODE       LATITUDE      LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  671716.000000  973789.000000  973789.000000               1.048558e+06
# mean    10869.603322      40.578954     -73.664801               3.208759e-01
# std       541.474709       2.437078       4.615412               7.026131e-01
# min     10000.000000       0.000000    -201.359990               0.000000e+00
# 25%     10453.000000      40.667347     -73.970480               0.000000e+00
# 50%     11208.000000      40.719760     -73.922554               0.000000e+00
# 75%     11249.000000      40.774292     -73.863560               0.000000e+00
# max     11697.000000      41.126150       0.000000               4.000000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.048545e+06                   1.048575e+06
# mean               1.480146e-03                   5.416685e-02
# std                4.070937e-02                   2.389199e-01
# ...

# %%
df.drop_duplicates()
# Out:
#          CRASH DATE   CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0        09/11/2021  02:39:00 AM       NaN       NaN        NaN        NaN
# 1        03/26/2022  11:45:00 AM       NaN       NaN        NaN        NaN
# 2        06/29/2022  06:55:00 AM       NaN       NaN        NaN        NaN
# 3        09/11/2021  09:35:00 AM  BROOKLYN   11208.0  40.667202 -73.866500
# 4        12/14/2021  08:13:00 AM  BROOKLYN   11233.0  40.683304 -73.917274
# ...             ...          ...       ...       ...        ...        ...
# 1048570  08/23/2016  04:55:00 PM       NaN       NaN  40.692722 -73.968750
# 1048571  09/11/2016  02:45:00 PM       NaN       NaN  40.733430 -73.868890
# 1048572  09/09/2016  05:00:00 PM       NaN       NaN  40.770065 -73.959274
# 1048573  09/05/2016  09:12:00 PM       NaN       NaN  40.617764 -74.135700
# 1048574  08/25/2016  02:00:00 PM  BROOKLYN   11226.0  40.650806 -73.949580
#
# ...

# %%
df.isnull().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           376675
# ZIP CODE                          376859
# LATITUDE                           74786
# LONGITUDE                          74786
# LOCATION                           74786
# ON STREET NAME                    257010
# CROSS STREET NAME                 542992
# OFF STREET NAME                   792893
# NUMBER OF PERSONS INJURED             17
# NUMBER OF PERSONS KILLED              30
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       3750
# CONTRIBUTING FACTOR VEHICLE 2     178459
# CONTRIBUTING FACTOR VEHICLE 3     970988
# CONTRIBUTING FACTOR VEHICLE 4    1030526
# CONTRIBUTING FACTOR VEHICLE 5    1043538
# ...

# %% [markdown]
# Data cleaning

# %%
df.drop(columns=['ZIP CODE'],inplace=True)
df.drop(columns=['LOCATION'],inplace=True)
df.drop(columns=['CROSS STREET NAME'],inplace=True)
df.drop(columns=['OFF STREET NAME'],inplace=True)
df.drop(columns=['CONTRIBUTING FACTOR VEHICLE 2'],inplace=True)
df.drop(columns=['CONTRIBUTING FACTOR VEHICLE 3'],inplace=True)
df.drop(columns=['CONTRIBUTING FACTOR VEHICLE 4'],inplace=True)
df.drop(columns=['CONTRIBUTING FACTOR VEHICLE 5'],inplace=True)
df.drop(columns=['VEHICLE TYPE CODE 2'],inplace=True)
df.drop(columns=['VEHICLE TYPE CODE 3'],inplace=True)
df.drop(columns=['VEHICLE TYPE CODE 4'],inplace=True)
df.drop(columns=['VEHICLE TYPE CODE 5'],inplace=True)

# %%
df.columns= [x.lower() for x in df.columns]
df.columns
# Out:
# Index(['crash date', 'crash time', 'borough', 'latitude', 'longitude',
#        'on street name', 'number of persons injured',
#        'number of persons killed', 'number of pedestrians injured',
#        'number of pedestrians killed', 'number of cyclist injured',
#        'number of cyclist killed', 'number of motorist injured',
#        'number of motorist killed', 'contributing factor vehicle 1',
#        'collision_id', 'vehicle type code 1'],
#       dtype='object')

# %%
df['crash date'] = df['crash date'].astype('datetime64')

# %%
df['crash time'] = df['crash time'].astype('datetime64')

# %%
df
# Out:
#         crash date          crash time   borough   latitude  longitude  \
# 0       2021-09-11 2023-05-31 02:39:00       NaN        NaN        NaN
# 1       2022-03-26 2023-05-31 11:45:00       NaN        NaN        NaN
# 2       2022-06-29 2023-05-31 06:55:00       NaN        NaN        NaN
# 3       2021-09-11 2023-05-31 09:35:00  BROOKLYN  40.667202 -73.866500
# 4       2021-12-14 2023-05-31 08:13:00  BROOKLYN  40.683304 -73.917274
# ...            ...                 ...       ...        ...        ...
# 1048570 2016-08-23 2023-05-31 16:55:00       NaN  40.692722 -73.968750
# 1048571 2016-09-11 2023-05-31 14:45:00       NaN  40.733430 -73.868890
# 1048572 2016-09-09 2023-05-31 17:00:00       NaN  40.770065 -73.959274
# 1048573 2016-09-05 2023-05-31 21:12:00       NaN  40.617764 -74.135700
# 1048574 2016-08-25 2023-05-31 14:00:00  BROOKLYN  40.650806 -73.949580
#
#                            on street name  number of persons injured  \
# ...

# %% [markdown]
# 1-Know the rate of accidents over the years

# %%
df.groupby(df['crash date'].dt.year)['collision_id'].count()
# Out:
# crash date
# 2012         4
# 2016     81684
# 2017    231007
# 2018    231563
# 2019    211486
# 2020    112909
# 2021    110528
# 2022     69394
# Name: collision_id, dtype: int64

# %%
years =df.groupby(df['crash date'].dt.year)['collision_id'].count()
years.plot().set_title('Accidents rate over years',fontdict={'size': 15, 'weight': 'bold'})

plt.show()

# %% [markdown]
# 2- Find out the most months in which accidents occur throughout the year

# %% [markdown]
# 3-Find out more hours of accidents throughout the year

# %%
accident_month = df.groupby(df['crash date'].dt.month)['collision_id'].count()
accident_month.plot().set_title('Accident rate over months',fontdict={'size': 15, 'weight': 'bold'})

plt.show()

# %% [markdown]
# Find out more streets where accidents occur throughout the year

# %%
hourly_accident = df.groupby(df['crash time'].dt.hour)['collision_id'].count()
hourly_accident.plot().set_title('Accident rate over day hours',fontdict={'size': 15, 'weight': 'bold'})

plt.show()

# %% [markdown]
# Know the rate of injuries over the years

# %%
contributing_factor = df.groupby(df['contributing factor vehicle 1'])['collision_id'].count()
factor =contributing_factor.sort_values(ascending = False).nlargest(11)
factor.plot.barh().set_title('The ten most  accidents streets',fontdict={'size': 15, 'weight': 'bold'})
plt.show()

# %%
injured_people = df.groupby(df['crash date'].dt.year)['number of persons injured'].sum()
injured_people.plot().set(title ='Injured rate over years')
plt.show()

# %%
pedestrians_injured = df['number of pedestrians injured'].sum()
motorist_injured = df['number of motorist injured'].sum()
cyclist_injured = df['number of cyclist injured'].sum()
injured = [pedestrians_injured , motorist_injured , cyclist_injured]
x_axis = ['pedestrians_injured' , 'motorist_injured' , 'cyclist_injured']
plt.bar (x_axis , injured)
plt.title = ('number of injured people in different category')

# %% [markdown]
# Know the rate of killed people over the years

# %%
killed_people = df.groupby(df['crash date'].dt.year)['number of persons killed'].sum()
killed_people.plot().set(title='Killed rate over years')
plt.show()

# %%
pedestrians_killed = df['number of pedestrians killed'].sum()
motorist_killed = df['number of motorist killed'].sum()
cyclist_killed = df['number of cyclist killed'].sum()
x_axis = ['pedestrians_killed' , 'motorist_killed' , 'cyclist_killed']
killed = [pedestrians_killed , motorist_killed , cyclist_killed]
plt.bar (x_axis,killed)
plt.title = ('number of killed people in different category')
